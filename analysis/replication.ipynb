# %% [markdown]
# # Minimal Reproduction: Hodler & Raschky (2014)
# # *Regional Favoritism*
#
# **Main specification:** Do leaders channel economic resources to their birth regions?
#
# $$\ln(\text{light}_{i,t}) = \beta \cdot \text{BirthRegionLeader}_{i,t} + \alpha_i + \gamma_{c,t} + \varepsilon_{i,t}$$
#
# - $\alpha_i$: region (ADM2) fixed effects
# - $\gamma_{c,t}$: country $\times$ year fixed effects
# - $\text{BirthRegionLeader}_{i,t} = 1$ if region $i$ is the birth region of the national leader in year $t$
#
# **Data:**
# - Political leaders: PLAD (Bomprezzi et al., 2025)
# - Nightlights: Harmonized DMSP-OLS / VIIRS (Li et al., 2020)
# - Admin boundaries: GADM v4.1 (ADM2 level, ~39,000 districts)

# %%
import os
import warnings
import zipfile
import urllib.request
from pathlib import Path

import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio
from rasterstats import zonal_stats
from linearmodels.panel import PanelOLS

warnings.filterwarnings("ignore")

ROOT = Path("..")  # project root
DATA = ROOT / "data"
NTL_DIR = DATA / "nightlights"
PLAD_PATH = DATA / "political leaders" / "PLAD_April_2024.dta"
SCRIPTS = (ROOT / "scripts").resolve()
if str(SCRIPTS) not in os.sys.path:
    os.sys.path.append(str(SCRIPTS))

from gid_utils import valid_gid_mask

# %% [markdown]
# ## 1. Download GADM ADM2 boundaries

# %%
GADM_DIR = DATA / "gadm"
GADM_GPKG = GADM_DIR / "gadm_410.gpkg"
ADM2_CACHE = GADM_DIR / "gadm41_adm2.gpkg"

# --- Download GADM if needed ---
if not GADM_GPKG.exists() and not ADM2_CACHE.exists():
    GADM_DIR.mkdir(parents=True, exist_ok=True)
    url = "https://geodata.ucdavis.edu/gadm/gadm4.1/gadm_410-gpkg.zip"
    zip_path = GADM_DIR / "gadm_410-gpkg.zip"
    print("Downloading GADM (~1.4 GB) — this may take a few minutes...")
    urllib.request.urlretrieve(url, zip_path)
    print("Extracting...")
    with zipfile.ZipFile(zip_path, "r") as zf:
        zf.extractall(GADM_DIR)
    zip_path.unlink()
    print("Done.")

# --- Dissolve to ADM2 level and cache ---
if ADM2_CACHE.exists():
    print(f"Loading cached ADM2 boundaries from {ADM2_CACHE}")
    adm2 = gpd.read_file(ADM2_CACHE)
    adm2 = adm2.loc[valid_gid_mask(adm2["GID_2"])].copy()
else:
    print("Reading GADM and dissolving to ADM2 (may take several minutes)...")
    raw = gpd.read_file(GADM_GPKG)

    # For countries that lack ADM2 subdivision, promote their ADM1 code to GID_2
    # (mirrors Bora 2025: "retain ADM1 regions for countries with no ADM2")
    has_gid2 = valid_gid_mask(raw["GID_2"])
    # Replace GID_2 in-place so dissolve key has no duplicate column after the operation
    raw["GID_2"] = raw["GID_2"].where(has_gid2, raw["GID_1"])

    adm2 = raw.dissolve(by="GID_2", as_index=False)
    keep_cols = [c for c in ["GID_0", "GID_1", "GID_2", "NAME_0", "NAME_1", "NAME_2", "geometry"]
                 if c in adm2.columns]
    adm2 = adm2[keep_cols]
    adm2 = adm2.loc[valid_gid_mask(adm2["GID_2"])].copy()
    adm2.to_file(ADM2_CACHE, driver="GPKG")
    print(f"Cached ADM2 boundaries to {ADM2_CACHE}")

print(f"Loaded {len(adm2)} ADM2 regions")
adm2.head(2)
# Out:
# Loading cached ADM2 boundaries from ../data/gadm/gadm41_adm2.gpkg
# Loaded 47984 ADM2 regions
#   GID_0    GID_1       GID_2       NAME_0      NAME_1         NAME_2  \
# 2   AFG  AFG.1_1  AFG.1.10_1  Afghanistan  Badakhshan  Shahri Buzurg
# 3   AFG  AFG.1_1  AFG.1.11_1  Afghanistan  Badakhshan       Shighnan
#
#                                             geometry
# 2  MULTIPOLYGON (((70.32571 37.46014, 70.3063 37....
# 3  MULTIPOLYGON (((71.31807 37.24994, 71.30699 37...

# %% [markdown]
# ## 2. Compute mean nightlights per ADM2-year (zonal statistics)
#
# We compute the mean nightlight intensity within each ADM2 polygon for each year of the harmonized DMSP rasters (1992–2013, matching the original paper's DMSP era).
#
# Using ADM2 (~39,000 districts) instead of ADM1 (~3,600 provinces) gives ~11× more regions, providing many more control units per treated birth district and substantially more statistical power.

# %%
PANEL_CACHE = DATA / "nightlights_adm2_panel.parquet"
YEARS = range(1992, 2014)  # 1992-2013 inclusive (DMSP era)

def raster_path(year):
    """Return the path to the harmonized nightlights raster for a given year."""
    if year <= 2013:
        return NTL_DIR / f"Harmonized_DN_NTL_{year}_calDMSP.tif"
    else:
        return NTL_DIR / f"Harmonized_DN_NTL_{year}_simVIIRS.tif"

if PANEL_CACHE.exists():
    print(f"Loading cached panel from {PANEL_CACHE}")
    ntl_panel = pd.read_parquet(PANEL_CACHE)
    ntl_panel = ntl_panel.loc[valid_gid_mask(ntl_panel["GID_2"])].copy()
else:
    frames = []
    for year in YEARS:
        rpath = raster_path(year)
        if not rpath.exists():
            print(f"  Skipping {year} — raster not found")
            continue
        print(f"  Processing {year}...", end=" ", flush=True)
        stats = zonal_stats(
            adm2.geometry,
            str(rpath),
            stats=["mean"],
            nodata=0,
        )
        means = [s["mean"] for s in stats]
        df_year = pd.DataFrame({
            "GID_2": adm2["GID_2"],
            "GID_1": adm2["GID_1"],
            "GID_0": adm2["GID_0"],
            "year": year,
            "ntl_mean": means,
        })
        frames.append(df_year)
        print(f"done (non-null: {df_year['ntl_mean'].notna().sum()})")

    ntl_panel = pd.concat(frames, ignore_index=True)
    ntl_panel = ntl_panel.loc[valid_gid_mask(ntl_panel["GID_2"])].copy()
    ntl_panel.to_parquet(PANEL_CACHE)
    print(f"\nSaved panel to {PANEL_CACHE}")

print(f"Panel shape: {ntl_panel.shape}")
ntl_panel.head()
# Out:
# Loading cached panel from ../data/nightlights_adm2_panel.parquet
# Panel shape: (1055648, 5)
#         GID_2    GID_1 GID_0  year  ntl_mean
# 2  AFG.1.10_1  AFG.1_1   AFG  1992       NaN
# 3  AFG.1.11_1  AFG.1_1   AFG  1992       NaN
# 4  AFG.1.12_1  AFG.1_1   AFG  1992       NaN
# 5  AFG.1.13_1  AFG.1_1   AFG  1992       NaN
# 6   AFG.1.1_1  AFG.1_1   AFG  1992       NaN

# %% [markdown]
# ## 3. Build treatment variable from PLAD

# %%
plad = pd.read_stata(PLAD_PATH)

# Keep domestic leaders with valid birth region identifiers
plad = plad[plad["foreign_leader"] == "0"].copy()

# Detect which GID level is available for birth region coding
gid_cols = [c for c in plad.columns if c.lower().startswith("gid_")]
print(f"GID columns in PLAD: {gid_cols}")

# Prefer gid_2 (ADM2 birth district, matching H&R/Bora); fall back to gid_1 (ADM1 province)
if "gid_2" in plad.columns:
    n_valid_gid2 = (plad["gid_2"].str.strip() != ".").sum()
    print(f"gid_2 non-missing: {n_valid_gid2} / {len(plad)}")
    BIRTH_GID = "gid_2"
    print("Using ADM2 birth regions (gid_2) — matches H&R / Bora 2025")
else:
    BIRTH_GID = "gid_1"
    print("WARNING: gid_2 not in PLAD — using gid_1 (ADM1). Treatment will be assigned to "
          "all ADM2 districts within the birth province.")

plad = plad.loc[valid_gid_mask(plad[BIRTH_GID])].copy()
plad["startyear"] = plad["startyear"].astype(int)
plad["endyear"] = plad["endyear"].astype(int)

# Restrict to leaders with an Archigos ID — matches H&R's "effective executive" definition
plad = plad[plad["archigos_id"].str.strip() != "."].copy()

# Sort by country then start year (required for overlap fix below)
plad = plad.sort_values(["gid_0", "startyear"]).reset_index(drop=True)

print(f"Leaders after filtering: {len(plad)}")
print(f"Unique countries: {plad['country'].nunique()}")
print(f"Year range: {plad['startyear'].min()}–{plad['endyear'].max()}")
plad[["leader", "country", BIRTH_GID, "startyear", "endyear"]].head(10)
# Out:
# GID columns in PLAD: ['gid_0', 'gid_1', 'gid_2']
# gid_2 non-missing: 1025 / 1253
# Using ADM2 birth regions (gid_2) — matches H&R / Bora 2025
# Leaders after filtering: 820
# Unique countries: 151
# Year range: 1948–2023
#                   leader      country       gid_2  startyear  endyear
# 0             Najibullah  Afghanistan  AFG.26.4_1       1986     1992
# 1               Mojadidi  Afghanistan  AFG.14.6_1       1992     1992
# 2            Mullah Omar  Afghanistan  AFG.15.6_1       1996     2001
# 3           Hamid Karzai  Afghanistan  AFG.15.5_1       2001     2014
# 4  Ashraf Ghani Ahmadzai  Afghanistan  AFG.14.8_1       2014     2021
# 5             Dos Santos       Angola  AGO.11.8_1       1979     2017
# 6                   Alia      Albania  ALB.10.3_1       1985     1992
# 7                Berisha      Albania   ALB.8.3_1       1992     1997
# 8             Fatos Nano      Albania  ALB.11.2_1       1997     1998
# ...

# %%
# --- Fix 1: Resolve transition-year overlap ---
# PLAD codes outgoing leader's endyear == incoming leader's startyear,
# so naively both are treated in the same year. We clip each leader's
# endyear to (next leader's startyear - 1) within the same country.
plad_fixed = plad.copy().reset_index(drop=True)

for gid_0, group in plad_fixed.groupby("gid_0"):
    idxs = group.index.tolist()
    for i in range(len(idxs) - 1):
        curr, nxt = idxs[i], idxs[i + 1]
        if plad_fixed.loc[curr, "endyear"] >= plad_fixed.loc[nxt, "startyear"]:
            plad_fixed.loc[curr, "endyear"] = plad_fixed.loc[nxt, "startyear"] - 1

n_fixed = (plad_fixed["endyear"] != plad["endyear"]).sum()
print(f"Overlapping spells clipped: {n_fixed}")

# Expand spells into birth-region × year rows
rows = []
for idx, row in plad_fixed.iterrows():
    for y in range(max(int(row["startyear"]), 1992), min(int(row["endyear"]), 2013) + 1):
        rows.append({"GID_2": row[BIRTH_GID], "GID_0": row["gid_0"], "year": y, "spell_id": idx})

leader_years = pd.DataFrame(rows)
leader_years = leader_years.loc[valid_gid_mask(leader_years["GID_2"])].copy()

# If PLAD only has ADM1 codes, expand each birth ADM1 to all constituent ADM2 districts
if BIRTH_GID == "gid_1":
    adm1_to_adm2 = ntl_panel[["GID_2", "GID_1"]].drop_duplicates()
    leader_years = (
        leader_years
        .rename(columns={"GID_2": "GID_1"})
        .merge(adm1_to_adm2, on="GID_1", how="inner")
        [["GID_2", "GID_0", "year", "spell_id"]]
    )
    print(f"Expanded ADM1 birth regions → {len(leader_years)} ADM2-year rows")

# Sanity check: at most 1 treated leader per country-year (only meaningful for ADM2 birth codes)
multi = leader_years.groupby(["GID_0", "year"])["GID_2"].nunique()
n_multi = (multi > 1).sum()
print(f"Country-years with >1 treated region: {n_multi}"
      + ("  (should be 0)" if BIRTH_GID == "gid_2" else "  (expected for ADM1 expansion)"))

leader_years = leader_years.drop_duplicates(subset=["GID_2", "year"])
leader_years["birth_region_leader"] = 1
print(f"Birth-region × year observations: {len(leader_years)}")

# --- Build country-year → leader-spell mapping for SE clustering ---
# All regions in a country share the same cluster ID for a given leader's tenure.
spell_map = leader_years[["GID_0", "year", "spell_id"]].drop_duplicates(subset=["GID_0", "year"])
print(f"Unique leader spells active in panel: {spell_map['spell_id'].nunique()}")
# Out:
# Overlapping spells clipped: 590
# Country-years with >1 treated region: 0  (should be 0)
# Birth-region × year observations: 3002
# Unique leader spells active in panel: 631

# %%
# --- Fix 2: GID_2 match rate diagnostic ---
# Check how many PLAD birth region codes actually match GADM GID_2 codes in the panel.
plad_gids  = set(plad_fixed[BIRTH_GID].unique())
panel_gids = set(ntl_panel["GID_2"].unique())

matched   = plad_gids & panel_gids
unmatched = plad_gids - panel_gids

level_label = "GID_2" if BIRTH_GID == "gid_2" else "GID_1→GID_2"
print(f"Unique {level_label} codes in PLAD:              {len(plad_gids)}")
print(f"Unique GID_2 codes in nightlights panel:         {len(panel_gids)}")
print(f"Matched (appear in both):                        {len(matched)}  ({len(matched)/len(plad_gids):.1%})")
print(f"Unmatched (PLAD birth regions with no NTL data): {len(unmatched)}")

if unmatched:
    unmatched_leaders = plad_fixed[plad_fixed[BIRTH_GID].isin(unmatched)][
        ["leader", "country", BIRTH_GID]
    ]
    print(f"\nLeaders with unmatched birth regions: {len(unmatched_leaders)}")
    print(unmatched_leaders.to_string())
# Out:
# Unique GID_2 codes in PLAD:              579
# Unique GID_2 codes in nightlights panel:         47984
# Matched (appear in both):                        538  (92.9%)
# Unmatched (PLAD birth regions with no NTL data): 41
#
# Leaders with unmatched birth regions: 58
#                       leader      country         gid_2
# 31                 Vranitzky      Austria     AUT.9.1_1
# 32                     Klima      Austria    AUT.3.14_1
# 33                  Schussel      Austria     AUT.9.1_1
# 34                Gusenbauer      Austria    AUT.3.17_1
# 35                   Faymann      Austria     AUT.9.1_1
# 66                     Ahmed   Bangladesh    BGD.3.13_1
# 108               Paz Zamora      Bolivia     BOL.2.6_1
# 109            Banzer Suarez      Bolivia     BOL.8.1_1
# 110    Jorge Quiroga Ramirez      Bolivia     BOL.2.6_1
# 111       Enrique RodrÃ­guez      Bolivia     BOL.2.6_1
# 112             Juan Morales      Bolivia     BOL.5.9_1
# ...

# %%
# Merge treatment onto panel
panel = ntl_panel.merge(leader_years[["GID_2", "year", "birth_region_leader"]],
                        on=["GID_2", "year"], how="left")
panel["birth_region_leader"] = panel["birth_region_leader"].fillna(0).astype(int)

# Merge leader-period spell ID for clustering (all regions in a country-year
# share the cluster of whichever leader was in power that year)
panel = panel.merge(spell_map[["GID_0", "year", "spell_id"]], on=["GID_0", "year"], how="left")
# Fallback: country-year string for obs with no leader record (acts as singleton clusters)
panel["spell_id"] = panel["spell_id"].fillna(
    panel["GID_0"] + "_" + panel["year"].astype(str) + "_noleader"
).astype(str)

# Add lag 1 and lag 2 of treatment (computed before dropping NaN rows to
# avoid incorrectly skipping years with missing nightlights)
panel = panel.sort_values(["GID_2", "year"])
panel["brl_lag1"] = panel.groupby("GID_2")["birth_region_leader"].shift(1).fillna(0).astype(int)
panel["brl_lag2"] = panel.groupby("GID_2")["birth_region_leader"].shift(2).fillna(0).astype(int)

# Construct log nightlights and country-year FE identifier
panel["ln_ntl"] = np.log(panel["ntl_mean"] + 0.01)
panel["country_year"] = panel["GID_0"] + "_" + panel["year"].astype(str)

# Drop rows with missing nightlights
panel = panel.dropna(subset=["ntl_mean"])

print(f"Final panel: {panel.shape[0]} obs, {panel['GID_2'].nunique()} regions, "
      f"{panel['year'].nunique()} years")
print(f"Treated obs (birth_region_leader=1): {panel['birth_region_leader'].sum()}")
print(f"Treated obs (lag 1):                 {panel['brl_lag1'].sum()}")
print(f"Treated obs (lag 2):                 {panel['brl_lag2'].sum()}")
print(f"Unique leader-period clusters:       {panel['spell_id'].nunique()}")
panel.head()
# Out:
# Final panel: 951915 obs, 46566 regions, 22 years
# Treated obs (birth_region_leader=1): 2522
# Treated obs (lag 1):                 2406
# Treated obs (lag 2):                 2297
# Unique leader-period clusters:       2723
#              GID_2    GID_1 GID_0  year  ntl_mean  birth_region_leader  \
# 47985   AFG.1.11_1  AFG.1_1   AFG  1993  5.000000                    0
# 95969   AFG.1.11_1  AFG.1_1   AFG  1994  5.333333                    0
# 143953  AFG.1.11_1  AFG.1_1   AFG  1995  6.866667                    0
# 191937  AFG.1.11_1  AFG.1_1   AFG  1996  6.285714                    0
# 239921  AFG.1.11_1  AFG.1_1   AFG  1997  7.500000                    0
#
#                  spell_id  brl_lag1  brl_lag2    ln_ntl country_year
# 47985   AFG_1993_noleader         0         0  1.611436     AFG_1993
# 95969   AFG_1994_noleader         0         0  1.675850     AFG_1994
# 143953  AFG_1995_noleader         0         0  1.928134     AFG_1995
# ...

# %% [markdown]
# ## 4. Main regression
#
# $$\ln(\text{light}_{i,t}) = \beta \cdot \text{BirthRegionLeader}_{i,t} + \alpha_i + \gamma_{c,t} + \varepsilon_{i,t}$$
#
# Standard errors clustered at the country level, following Hodler & Raschky (2014).

# %%
# Main specification: region FE + country×year FE
# Clustered at leader-period level (Bora 2025 / H&R convention)
if not isinstance(panel.index, pd.MultiIndex):
    panel = panel.set_index(["GID_2", "year"])

specs = [
    ("Lag 0", "birth_region_leader"),
    ("Lag 1", "brl_lag1"),
    ("Lag 2", "brl_lag2"),
]

rows = []
for label, var in specs:
    model = PanelOLS.from_formula(
        f"ln_ntl ~ {var} + EntityEffects",
        data=panel,
        other_effects=panel["country_year"],
        drop_absorbed=True,
    )
    res = model.fit(cov_type="clustered", clusters=panel["spell_id"])
    coef  = res.params[var]
    se    = res.std_errors[var]
    pval  = res.pvalues[var]
    stars = "***" if pval < 0.01 else "**" if pval < 0.05 else "*" if pval < 0.1 else ""
    rows.append({
        "Spec":        label,
        "Coeff":       f"{coef:.4f}{stars}",
        "Std. Err.":   f"({se:.4f})",
        "p-value":     f"{pval:.3f}",
        "N":           f"{res.nobs:,}",
    })

import pandas as pd
print("Dep. var: log(nightlights + 0.01)")
print("FE: Region (ADM2) + Country×Year  |  Clustering: Leader-period\n")
print(pd.DataFrame(rows).set_index("Spec").to_string())
print("\nSignificance: *** p<0.01, ** p<0.05, * p<0.1")
# Out:
# Dep. var: log(nightlights + 0.01)
# FE: Region (ADM2) + Country×Year  |  Clustering: Leader-period
#
#            Coeff Std. Err. p-value        N
# Spec
# Lag 0   0.0128**  (0.0059)   0.030  951,915
# Lag 1  0.0171***  (0.0056)   0.002  951,915
# Lag 2  0.0143***  (0.0055)   0.010  951,915
#
# Significance: *** p<0.01, ** p<0.05, * p<0.1

# %% [markdown]
# ## 5. Replication diagnostics: when does the coefficient fade?
#
# The main puzzle is that the Hodler & Raschky / Bora replication works in the long DMSP window but fades in later subsamples. We diagnose this in three complementary ways:
#
# 1. **Nested end-equivalent windows**: rerun the same fixed-effects specification on `1992–2013`, `1995–2013`, `2000–2013`, and `2005–2013`.
# 2. **Full start/end grids**: estimate every valid window in a DMSP-only grid (`1992–2013`) and a later harmonized grid (`2005–2019`) to see whether attenuation is driven more by dropping early years, later end years, or both.
# 3. **Pooled decade interaction**: estimate the full `1992–2013` panel with `BirthRegion × post2000` and `BirthRegion × post2010` interactions.
#
# Taken together, these diagnostics separate three questions: whether the original replication survives once we trim the early years, whether weakening appears broadly across start/end windows, and whether a simple decade break captures the pattern.

# %%
# Helper functions for time-window diagnostics
if not isinstance(panel.index, pd.MultiIndex):
    panel = panel.set_index(["GID_2", "year"])

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from IPython.display import display

def _stars(pval):
    return "***" if pval < 0.01 else "**" if pval < 0.05 else "*" if pval < 0.1 else ""

def _window_label(start, end):
    return f"{start}–{end}"

def run_brl_spec(data, var):
    model = PanelOLS.from_formula(
        f"ln_ntl ~ {var} + EntityEffects",
        data=data,
        other_effects=data["country_year"],
        drop_absorbed=True,
    )
    res = model.fit(cov_type="clustered", clusters=data["spell_id"])
    return {
        "coef": res.params[var],
        "se": res.std_errors[var],
        "pval": res.pvalues[var],
        "nobs": int(res.nobs),
        "treated": int(data[var].sum()),
        "clusters": int(data["spell_id"].nunique()),
    }

def build_window_grid_results(base_panel, var, start_year, end_year, min_window_years=8):
    years = base_panel.index.get_level_values("year")
    records = []
    for start in range(start_year, end_year + 1):
        min_end = start + min_window_years - 1
        for end in range(min_end, end_year + 1):
            sub = base_panel[(years >= start) & (years <= end)].copy()
            out = run_brl_spec(sub, var)
            records.append({
                "Window": _window_label(start, end),
                "Start": start,
                "End": end,
                "window_years": end - start + 1,
                **out,
            })
    return pd.DataFrame(records).sort_values(["Start", "End"]).reset_index(drop=True)

def build_window_grid_shortlist(results, key_windows, top_n=5, weakest_n=5):
    top_positive = results.nlargest(top_n, "coef").copy()
    top_positive["Category"] = "Top positive"

    weakest = (
        results.assign(abs_coef=results["coef"].abs())
        .nsmallest(weakest_n, "abs_coef")
        .drop(columns=["abs_coef"])
        .copy()
    )
    weakest["Category"] = "Weakest / near zero"

    key = pd.DataFrame(key_windows, columns=["Start", "End"]).merge(
        results, on=["Start", "End"], how="left"
    )
    key["Category"] = "Key windows"

    shortlist = pd.concat([top_positive, weakest, key], ignore_index=True)
    shortlist["Category"] = pd.Categorical(
        shortlist["Category"],
        categories=["Top positive", "Weakest / near zero", "Key windows"],
        ordered=True,
    )
    shortlist = shortlist.drop_duplicates(subset=["Category", "Start", "End"])
    shortlist = shortlist.sort_values(["Category", "Start", "End"]).reset_index(drop=True)
    return shortlist[["Category", "Window", "Start", "End", "window_years", "coef", "se", "pval", "nobs", "treated", "clusters"]]

def plot_window_grid_heatmap(results, title, ax=None, vlim=None):
    if ax is None:
        _, ax = plt.subplots(figsize=(8, 6))

    starts = sorted(results["Start"].unique())
    ends = sorted(results["End"].unique())

    coef_grid = results.pivot(index="Start", columns="End", values="coef").reindex(index=starts, columns=ends)
    pval_grid = results.pivot(index="Start", columns="End", values="pval").reindex(index=starts, columns=ends)
    nobs_grid = results.pivot(index="Start", columns="End", values="nobs").reindex(index=starts, columns=ends)
    thin_cutoff = results["nobs"].quantile(0.25)

    vmax = vlim if vlim is not None else np.nanmax(np.abs(coef_grid.values))
    im = ax.imshow(coef_grid.values, cmap="coolwarm", vmin=-vmax, vmax=vmax, aspect="auto", origin="upper")

    for i, start in enumerate(starts):
        for j, end in enumerate(ends):
            coef = coef_grid.iloc[i, j]
            if pd.isna(coef):
                ax.add_patch(Rectangle((j - 0.5, i - 0.5), 1, 1, facecolor="white", edgecolor="white"))
                continue
            muted = (pval_grid.iloc[i, j] >= 0.10) or (nobs_grid.iloc[i, j] <= thin_cutoff)
            if muted:
                ax.add_patch(Rectangle((j - 0.5, i - 0.5), 1, 1, facecolor="white", alpha=0.45, edgecolor="none"))

    ax.set_xticks(range(len(ends)))
    ax.set_xticklabels(ends, rotation=45, ha="right")
    ax.set_yticks(range(len(starts)))
    ax.set_yticklabels(starts)
    ax.set_xlabel("Window end year")
    ax.set_ylabel("Window start year")
    ax.set_title(title)
    ax.set_xticks(np.arange(-0.5, len(ends), 1), minor=True)
    ax.set_yticks(np.arange(-0.5, len(starts), 1), minor=True)
    ax.grid(which="minor", color="white", linestyle="-", linewidth=0.5)
    ax.tick_params(which="minor", bottom=False, left=False)
    plt.colorbar(im, ax=ax, shrink=0.85, label="Lag 0 coefficient")
    return thin_cutoff

# %%
# Nested windows: does the coefficient disappear as we drop earlier years?
windows = [
    ("1992–2013", 1992, 2013),
    ("1995–2013", 1995, 2013),
    ("2000–2013", 2000, 2013),
    ("2005–2013", 2005, 2013),
]
specs_diag = [
    ("Lag 0", "birth_region_leader"),
    ("Lag 1", "brl_lag1"),
    ("Lag 2", "brl_lag2"),
]

diag_results = []
formatted_rows = []
for spec_label, var in specs_diag:
    row_coef = {"Spec": spec_label}
    row_se = {"Spec": ""}
    for window_label, start, end in windows:
        sub = panel[(panel.index.get_level_values("year") >= start) &
                    (panel.index.get_level_values("year") <= end)].copy()
        out = run_brl_spec(sub, var)
        diag_results.append({
            "Spec": spec_label,
            "Window": window_label,
            "Start": start,
            **out,
        })
        row_coef[window_label] = f"{out['coef']:.4f}{_stars(out['pval'])}"
        row_se[window_label] = f"({out['se']:.4f})"
    formatted_rows.extend([row_coef, row_se])

diag_results = pd.DataFrame(diag_results)
window_table = pd.DataFrame(formatted_rows).set_index("Spec")

meta_rows = []
for metric, label in [("nobs", "N"), ("treated", "Treated obs"), ("clusters", "Leader-period clusters")]:
    row = {"Spec": label}
    for window_label, _, _ in windows:
        value = int(diag_results[(diag_results["Spec"] == "Lag 0") & (diag_results["Window"] == window_label)][metric].iloc[0])
        row[window_label] = f"{value:,}"
    meta_rows.append(row)

window_table = pd.concat([window_table, pd.DataFrame(meta_rows).set_index("Spec")])
print("Dep. var: log(nightlights + 0.01)")
print("FE: Region (ADM2) + Country×Year  |  Clustering: Leader-period\n")
print(window_table.to_string())
print("\nInterpretation: the coefficient remains positive through 2000–2013 and then collapses in 2005–2013,")
print("which points to a later-window attenuation rather than a purely late-1990s-driven result.")
# Out:
# Dep. var: log(nightlights + 0.01)
# FE: Region (ADM2) + Country×Year  |  Clustering: Leader-period
#
#                         1992–2013  1995–2013 2000–2013 2005–2013
# Spec
# Lag 0                    0.0128**  0.0187***   0.0110*    0.0017
#                          (0.0059)   (0.0055)  (0.0058)  (0.0058)
# Lag 1                   0.0171***  0.0189***   0.0109*   -0.0033
#                          (0.0056)   (0.0054)  (0.0059)  (0.0066)
# Lag 2                   0.0143***  0.0169***  0.0119**    0.0032
#                          (0.0055)   (0.0052)  (0.0057)  (0.0063)
# N                         951,915    829,988   615,660   398,636
# Treated obs                 2,522      2,196     1,647     1,068
# Leader-period clusters      2,723      2,358     1,759     1,186
#
# Interpretation: the coefficient remains positive through 2000–2013 and then collapses in 2005–2013,
# which points to a later-window attenuation rather than a purely late-1990s-driven result.

# %%
# Pooled decade interaction on the full 1992–2013 sample
panel_dec = panel.copy()
panel_dec["post2000"] = (panel_dec.index.get_level_values("year") >= 2000).astype(int)
panel_dec["post2010"] = (panel_dec.index.get_level_values("year") >= 2010).astype(int)
panel_dec["br_x_post2000"] = panel_dec["birth_region_leader"] * panel_dec["post2000"]
panel_dec["br_x_post2010"] = panel_dec["birth_region_leader"] * panel_dec["post2010"]

res_dec = PanelOLS.from_formula(
    "ln_ntl ~ birth_region_leader + br_x_post2000 + br_x_post2010 + EntityEffects",
    data=panel_dec,
    other_effects=panel_dec["country_year"],
    drop_absorbed=True,
).fit(cov_type="clustered", clusters=panel_dec["spell_id"])

rows_dec = []
for label, var in [("BirthRegion (1990s baseline)", "birth_region_leader"),
                   ("BirthRegion × post2000", "br_x_post2000"),
                   ("BirthRegion × post2010", "br_x_post2010")]:
    coef = res_dec.params[var]
    se = res_dec.std_errors[var]
    pval = res_dec.pvalues[var]
    rows_dec.append({
        "Term": label,
        "Coeff": f"{coef:.4f}{_stars(pval)}",
        "Std. Err.": f"({se:.4f})",
        "p-value": f"{pval:.3f}",
    })

print("Dep. var: log(nightlights + 0.01)")
print("FE: Region (ADM2) + Country×Year  |  Clustering: Leader-period\n")
print(pd.DataFrame(rows_dec).set_index("Term").to_string())
print(f"\nN = {int(res_dec.nobs):,} | Clusters = {panel_dec['spell_id'].nunique():,}")
print("Interpretation: the pooled decade interactions do not show a statistically distinct 2000s or 2010s effect relative to the 1990s.")
# Out:
# Dep. var: log(nightlights + 0.01)
# FE: Region (ADM2) + Country×Year  |  Clustering: Leader-period
#
#                                 Coeff Std. Err. p-value
# Term
# BirthRegion (1990s baseline)   0.0142  (0.0096)   0.137
# BirthRegion × post2000        -0.0053  (0.0115)   0.643
# BirthRegion × post2010         0.0097  (0.0126)   0.441
#
# N = 951,915 | Clusters = 2,723
# Interpretation: the pooled decade interactions do not show a statistically distinct 2000s or 2010s effect relative to the 1990s.

# %%
# Optional figure: Lag 0 coefficient across nested windows
import matplotlib.pyplot as plt

lag0_plot = diag_results[diag_results["Spec"] == "Lag 0"].copy().sort_values("Start")

fig, ax = plt.subplots(figsize=(7, 4))
ax.errorbar(lag0_plot["Start"], lag0_plot["coef"],
            yerr=1.96 * lag0_plot["se"], fmt="o-", capsize=4, color="black")
ax.axhline(0, color="gray", linestyle="--", linewidth=1)
ax.set_xlabel("Window start year")
ax.set_ylabel("Birth-region coefficient")
ax.set_title("Replication coefficient fades only in the post-2005 window")
ax.set_xticks(lag0_plot["Start"])
plt.show()

# %% [markdown]
# ## 5A. Full start/end window grids
#
# The fixed-end nested windows above isolate what happens when we drop early years while holding `2013` fixed. To see whether that pattern generalizes, we now estimate every valid Lag 0 window in two grids:
#
# - a DMSP-only grid on `1992-2013`
# - a harmonized later grid on `2005-2019`
#
# Both grids use the same birth-region specification, fixed effects, and leader-period clustering as the main replication. Cells with `p >= 0.10` or unusually thin samples are muted in the heatmaps rather than omitted.

# %%
MIN_WINDOW_YEARS = 8
GRID_VAR = "birth_region_leader"
HARMONIZED_NTL_CACHE = DATA / "nightlights_adm2_green_favoritism_panel.parquet"

def build_replication_panel(ntl_source, start_year, end_year):
    base = ntl_source.loc[
        (ntl_source["year"] >= start_year) & (ntl_source["year"] <= end_year)
    ].copy()
    base = base.loc[valid_gid_mask(base["GID_2"])].copy()

    rows = []
    for idx, row in plad_fixed.iterrows():
        spell_start = max(int(row["startyear"]), start_year)
        spell_end = min(int(row["endyear"]), end_year)
        if spell_start > spell_end:
            continue
        for year in range(spell_start, spell_end + 1):
            rows.append({
                "GID_2": row[BIRTH_GID],
                "GID_0": row["gid_0"],
                "year": year,
                "spell_id": idx,
            })

    leader_years_window = pd.DataFrame(rows)
    leader_years_window = leader_years_window.loc[
        valid_gid_mask(leader_years_window["GID_2"])
    ].copy()

    if BIRTH_GID == "gid_1":
        adm1_to_adm2 = base[["GID_2", "GID_1"]].drop_duplicates()
        leader_years_window = (
            leader_years_window
            .rename(columns={"GID_2": "GID_1"})
            .merge(adm1_to_adm2, on="GID_1", how="inner")
            [["GID_2", "GID_0", "year", "spell_id"]]
        )

    leader_years_window = leader_years_window.drop_duplicates(subset=["GID_2", "year"])
    leader_years_window["birth_region_leader"] = 1

    spell_map_window = leader_years_window[["GID_0", "year", "spell_id"]].drop_duplicates(
        subset=["GID_0", "year"]
    )

    panel_window = base.merge(
        leader_years_window[["GID_2", "year", "birth_region_leader"]],
        on=["GID_2", "year"],
        how="left",
    )
    panel_window["birth_region_leader"] = panel_window["birth_region_leader"].fillna(0).astype(int)

    panel_window = panel_window.merge(
        spell_map_window[["GID_0", "year", "spell_id"]],
        on=["GID_0", "year"],
        how="left",
    )
    panel_window["spell_id"] = panel_window["spell_id"].fillna(
        panel_window["GID_0"] + "_" + panel_window["year"].astype(str) + "_noleader"
    ).astype(str)

    panel_window = panel_window.sort_values(["GID_2", "year"])
    panel_window["brl_lag1"] = (
        panel_window.groupby("GID_2")["birth_region_leader"].shift(1).fillna(0).astype(int)
    )
    panel_window["brl_lag2"] = (
        panel_window.groupby("GID_2")["birth_region_leader"].shift(2).fillna(0).astype(int)
    )
    panel_window["ln_ntl"] = np.log(panel_window["ntl_mean"] + 0.01)
    panel_window["country_year"] = panel_window["GID_0"] + "_" + panel_window["year"].astype(str)
    panel_window = panel_window.dropna(subset=["ntl_mean"])
    return panel_window.set_index(["GID_2", "year"]).sort_index()

if not HARMONIZED_NTL_CACHE.exists():
    raise FileNotFoundError(
        f"Missing {HARMONIZED_NTL_CACHE}. Build the harmonized 2005-2019 panel first."
    )

harmonized_ntl_panel = pd.read_parquet(HARMONIZED_NTL_CACHE)
harmonized_ntl_panel = harmonized_ntl_panel.loc[
    valid_gid_mask(harmonized_ntl_panel["GID_2"])
].copy()

harmonized_panel = build_replication_panel(harmonized_ntl_panel, 2005, 2019)

dmsp_window_grid_results = build_window_grid_results(panel, GRID_VAR, 1992, 2013, MIN_WINDOW_YEARS)
harmonized_window_grid_results = build_window_grid_results(
    harmonized_panel, GRID_VAR, 2005, 2019, MIN_WINDOW_YEARS
)

for label, results, start_year, end_year in [
    ("DMSP", dmsp_window_grid_results, 1992, 2013),
    ("Harmonized", harmonized_window_grid_results, 2005, 2019),
]:
    assert (results["window_years"] >= MIN_WINDOW_YEARS).all(), f"{label} grid includes short windows"
    assert results["Start"].min() == start_year and results["End"].max() == end_year

for start, end in [(1992, 2013), (1995, 2013), (2000, 2013), (2005, 2013)]:
    assert ((dmsp_window_grid_results["Start"] == start) & (dmsp_window_grid_results["End"] == end)).any()

for start, end in [(2005, 2019), (2008, 2019), (2005, 2016), (2010, 2019)]:
    assert ((harmonized_window_grid_results["Start"] == start) & (harmonized_window_grid_results["End"] == end)).any()

dmsp_validation = (
    diag_results.loc[diag_results["Spec"] == "Lag 0", ["Window", "Start", "coef", "se", "pval", "nobs", "treated", "clusters"]]
    .assign(End=2013)
    .merge(
        dmsp_window_grid_results[["Window", "Start", "End", "coef", "se", "pval", "nobs", "treated", "clusters"]],
        on=["Window", "Start", "End"],
        how="left",
        suffixes=("_nested", "_grid"),
    )
)

for col in ["coef", "se", "pval"]:
    assert np.allclose(dmsp_validation[f"{col}_nested"], dmsp_validation[f"{col}_grid"])
for col in ["nobs", "treated", "clusters"]:
    assert (dmsp_validation[f"{col}_nested"] == dmsp_validation[f"{col}_grid"]).all()

dmsp_window_grid_shortlist = build_window_grid_shortlist(
    dmsp_window_grid_results,
    key_windows=[(1992, 2013), (1995, 2013), (2000, 2013), (2005, 2013)],
)
harmonized_window_grid_shortlist = build_window_grid_shortlist(
    harmonized_window_grid_results,
    key_windows=[(2005, 2019), (2005, 2016), (2008, 2019), (2010, 2019)],
)

for df, out_path in [
    (dmsp_window_grid_results, DATA / "replication_dmsp_window_grid_results.csv"),
    (harmonized_window_grid_results, DATA / "replication_harmonized_window_grid_results.csv"),
    (dmsp_window_grid_shortlist, DATA / "replication_dmsp_window_grid_shortlist.csv"),
    (harmonized_window_grid_shortlist, DATA / "replication_harmonized_window_grid_shortlist.csv"),
]:
    df.to_csv(out_path, index=False)

print("Validated that the DMSP grid reproduces the existing fixed-end Lag 0 estimates.")
print("Saved window-grid result tables to data/ as lightweight CSV files.")
display(dmsp_validation[["Window", "coef_nested", "coef_grid", "se_nested", "se_grid", "pval_nested", "pval_grid"]])
# Out:
# Validated that the DMSP grid reproduces the existing fixed-end Lag 0 estimates.
# Saved window-grid result tables to data/ as lightweight CSV files.
#       Window  coef_nested  coef_grid  se_nested   se_grid  pval_nested  \
# 0  1992–2013     0.012785   0.012785   0.005879  0.005879     0.029663
# 1  1995–2013     0.018741   0.018741   0.005462  0.005462     0.000601
# 2  2000–2013     0.011023   0.011023   0.005768  0.005768     0.056002
# 3  2005–2013     0.001723   0.001723   0.005849  0.005849     0.768335
#
#    pval_grid
# 0   0.029663
# 1   0.000601
# 2   0.056002
# 3   0.768335

# %%
def format_window_grid_shortlist(df):
    formatted = df.copy()
    for col in ["coef", "se", "pval"]:
        formatted[col] = formatted[col].map(lambda value: f"{value:.4f}")
    for col in ["window_years", "nobs", "treated", "clusters"]:
        formatted[col] = formatted[col].map(lambda value: f"{int(value):,}")
    return formatted

common_vlim = max(
    dmsp_window_grid_results["coef"].abs().max(),
    harmonized_window_grid_results["coef"].abs().max(),
)

fig, axes = plt.subplots(1, 2, figsize=(15, 6), constrained_layout=True)
dmsp_thin_cutoff = plot_window_grid_heatmap(
    dmsp_window_grid_results,
    "DMSP grid (1992-2013)",
    ax=axes[0],
    vlim=common_vlim,
)
harmonized_thin_cutoff = plot_window_grid_heatmap(
    harmonized_window_grid_results,
    "Harmonized grid (2005-2019)",
    ax=axes[1],
    vlim=common_vlim,
)
fig.suptitle("Lag 0 birth-region coefficient across all valid windows", y=1.04)
plt.show()
fig.savefig("Lag 0 birth-region coefficient across all valid windows.png")

print(
    f"Muted cells satisfy p >= 0.10 or fall at/below the bottom-quartile N cutoff within each grid "
    f"(DMSP cutoff = {dmsp_thin_cutoff:,.0f}; harmonized cutoff = {harmonized_thin_cutoff:,.0f})."
)

print("\nDMSP shortlist")
display(format_window_grid_shortlist(dmsp_window_grid_shortlist))

print("\nHarmonized shortlist")
display(format_window_grid_shortlist(harmonized_window_grid_shortlist))
# Out:
# Muted cells satisfy p >= 0.10 or fall at/below the bottom-quartile N cutoff within each grid (DMSP cutoff = 426,250; harmonized cutoff = 399,398).
#
# DMSP shortlist
#                Category     Window  Start   End window_years     coef      se  \
# 0          Top positive  1995–2010   1995  2010           16   0.0202  0.0052
# 1          Top positive  1996–2010   1996  2010           15   0.0205  0.0053
# 2          Top positive  1996–2011   1996  2011           16   0.0200  0.0054
# 3          Top positive  1997–2007   1997  2007           11   0.0200  0.0057
# 4          Top positive  1997–2010   1997  2010           14   0.0202  0.0054
# 5   Weakest / near zero  1992–2004   1992  2004           13  -0.0011  0.0066
# 6   Weakest / near zero  1993–2004   1993  2004           12   0.0007  0.0065
# 7   Weakest / near zero  1994–2001   1994  2001            8  -0.0003  0.0067
# 8   Weakest / near zero  1994–2002   1994  2002            9   0.0011  0.0069
# ...

# %% [markdown]
# ## 6. Democracy interaction
#
# Hodler & Raschky's key finding is that regional favoritism is concentrated in **autocracies**. We interact `birth_region_leader` with a democracy index to test this.
#
# **Data:** V-Dem Electoral Democracy Index (`v2x_polyarchy`, 0–1).
# Download the **Country-Year Core** CSV from [v-dem.net/data](https://v-dem.net/data/the-v-dem-dataset/) (free, requires quick registration) and place the CSV file in `data/vdem/`.

# %%
VDEM_DIR = DATA / "vdem"
vdem_csv = list(VDEM_DIR.glob("*.csv")) if VDEM_DIR.exists() else []
assert vdem_csv, (
    "V-Dem CSV not found. Download the Country-Year Core CSV from "
    "https://v-dem.net/data/the-v-dem-dataset/ and place it in data/vdem/"
)

vdem = pd.read_csv(vdem_csv[0], low_memory=False)
# Keep only what we need: country code, year, polyarchy index
vdem = vdem[["country_text_id", "year", "v2x_polyarchy"]].rename(
    columns={"country_text_id": "GID_0", "v2x_polyarchy": "democracy"}
)
vdem = vdem.dropna(subset=["democracy"])
vdem = vdem[(vdem["year"] >= 1992) & (vdem["year"] <= 2013)]

print(f"V-Dem: {len(vdem)} country-year obs, {vdem['GID_0'].nunique()} countries")
vdem.head()
# Out:
# V-Dem: 3890 country-year obs, 179 countries
#     GID_0  year  democracy
# 203   MEX  1992      0.437
# 204   MEX  1993      0.447
# 205   MEX  1994      0.470
# 206   MEX  1995      0.480
# 207   MEX  1996      0.508

# %%
# Merge democracy scores onto panel and build interactions
panel_dem = panel.reset_index().merge(vdem, on=["GID_0", "year"], how="left")
panel_dem = panel_dem.dropna(subset=["democracy"])

panel_dem["birth_x_democracy"]     = panel_dem["birth_region_leader"] * panel_dem["democracy"]
panel_dem["brl_lag1_x_democracy"]  = panel_dem["brl_lag1"] * panel_dem["democracy"]
panel_dem["brl_lag2_x_democracy"]  = panel_dem["brl_lag2"] * panel_dem["democracy"]

print(f"Panel with democracy: {len(panel_dem)} obs")
panel_dem = panel_dem.set_index(["GID_2", "year"])

# Interaction specification:
# ln(light) = β1·BirthRegion + β2·BirthRegion×Democracy + α_i + γ_ct + ε
# β1 > 0: favoritism in full autocracies (democracy = 0)
# β2 < 0: favoritism attenuated in democracies

specs_dem = [
    ("Lag 0", "birth_region_leader", "birth_x_democracy"),
    ("Lag 1", "brl_lag1",            "brl_lag1_x_democracy"),
    ("Lag 2", "brl_lag2",            "brl_lag2_x_democracy"),
]

rows_dem = []
for label, var, inter in specs_dem:
    model_dem = PanelOLS.from_formula(
        f"ln_ntl ~ {var} + {inter} + EntityEffects",
        data=panel_dem,
        other_effects=panel_dem["country_year"],
        drop_absorbed=True,
    )
    res = model_dem.fit(cov_type="clustered", clusters=panel_dem["spell_id"])

    for name, key in [("BirthRegion", var), ("BirthRegion×Democracy", inter)]:
        coef  = res.params[key]
        se    = res.std_errors[key]
        pval  = res.pvalues[key]
        stars = "***" if pval < 0.01 else "**" if pval < 0.05 else "*" if pval < 0.1 else ""
        rows_dem.append({
            "Spec": label, "Variable": name,
            "Coeff": f"{coef:.4f}{stars}", "Std. Err.": f"({se:.4f})", "p-value": f"{pval:.3f}",
        })

print("\nDep. var: log(nightlights + 0.01)")
print("FE: Region (ADM2) + Country×Year  |  Clustering: Leader-period\n")
print(pd.DataFrame(rows_dem).set_index(["Spec", "Variable"]).to_string())
print("\nSignificance: *** p<0.01, ** p<0.05, * p<0.1")
# Out:
# Panel with democracy: 934615 obs
#
# Dep. var: log(nightlights + 0.01)
# FE: Region (ADM2) + Country×Year  |  Clustering: Leader-period
#
#                                 Coeff Std. Err. p-value
# Spec  Variable
# Lag 0 BirthRegion              0.0150  (0.0152)   0.322
#       BirthRegion×Democracy   -0.0043  (0.0210)   0.839
# Lag 1 BirthRegion            0.0311**  (0.0144)   0.031
#       BirthRegion×Democracy   -0.0238  (0.0194)   0.220
# Lag 2 BirthRegion            0.0336**  (0.0150)   0.025
#       BirthRegion×Democracy   -0.0325  (0.0201)   0.106
#
# Significance: *** p<0.01, ** p<0.05, * p<0.1
